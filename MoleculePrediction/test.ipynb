# %%
import pandas as pd
import pickle as pk
from rdkit import Chem
data_path_prefix = "../data/"

# %%
pt = Chem.GetPeriodicTable()

# %%
from mendeleev import get_table
ptable = get_table('elements')

# %%
ptable_access = {}
for _,row in ptable.iterrows():
    ptable_access[row["symbol"]] = row["atomic_number"]

# %%
ptable.loc[5]
# Out:
# annotation                                                     density(graphite),
# atomic_number                                                                    6
# atomic_radius                                                                   91
# atomic_volume                                                                  5.3
# block                                                                            p
# boiling_point                                                                 5100
# density                                                                       2.25
# description                      Carbon is a member of group 14 of the periodic...
# dipole_polarizability                                                         11.3
# electron_affinity                                                          1.26212
# electronic_configuration                                              [He] 2s2 2p2
# ...

# %%
train_properties = pd.read_csv(data_path_prefix + "train.csv")

# %%
set_of_train_molecules = set()

# %%
molecule = ""
for i, row in mc.iterrows():
    temp = row["molecule_name"]
    if molecule != temp:
        molecule = temp
        set_of_train_molecules.add(molecule)

# %%
set_of_train_molecules
# Out:
# {'dsgdb9nsd_000001',
#  'dsgdb9nsd_000002',
#  'dsgdb9nsd_000003',
#  'dsgdb9nsd_000005',
#  'dsgdb9nsd_000007'}

# %%
x = train_properties["atom_index_0"]

# %%
max = 0
for i in x.values:
    if i > max:
        max = i
print(max)
# Out:
# 28

# %%
mc.head(35)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>molecule_name</th>
#       <th>atom_index_0</th>
#       <th>atom_index_1</th>
#       <th>type</th>
#       <th>scalar_coupling_constant</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>dsgdb9nsd_000001</td>
#       <td>1</td>
#       <td>0</td>
#       <td>1JHC</td>
#       <td>84.80760</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>dsgdb9nsd_000001</td>
#       <td>1</td>
#       <td>2</td>
#       <td>2JHH</td>
#       <td>-11.25700</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
# ...

# %%
noble_gasses = [2,10,18,36,54,86]

# %%
noble_gas_configurations =
